# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.22.0 typeguard-2.13.3

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import scipy.io
import shutil
import csv
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cp -av

# %%
path_images = "/content/drive/MyDrive/data/training_images/"
path_annot = "/content/drive/MyDrive/data/train_solution_bounding_boxes (1).csv"


# list of paths to images and annotations
image_paths = [
    f for f in os.listdir(path_images) if os.path.isfile(os.path.join(path_images, f))
]
image_paths.sort()

# %%
file = open(path_annot)
csvreader = csv.reader(file)
annot = []
for row in csvreader:
  annot.append(row)
del annot[0]

# %%
image_size = 224  # resize input images to this size

images, targets = [], []

# loop over the annotations and images, preprocess them and store in lists
for i in range(0, len(annot)):
    # Access bounding box coordinates
    name=annot[i][0]
    print(path_images+name)
    for j in range(len(image_paths)):
      if (image_paths[j]==name):
        top_left_x, top_left_y = annot[i][1], annot[i][2]
        bottom_right_x, bottom_right_y = annot[i][3], annot[i][4]

    image = keras.utils.load_img(
        path_images + name,
    )
    (w, h) = image.size[:2]

    # resize train set images
    if i < int(len(annot) * 0.8):
        # resize image if it is for training dataset
        image = image.resize((image_size, image_size))

    # convert image to array and append to list
    images.append(keras.utils.img_to_array(image))

    # apply relative scaling to bounding boxes as per given image and append to list
    targets.append(
        (
            float(top_left_x) / w,
            float(top_left_y) / h,
            float(bottom_right_x) / w,
            float(bottom_right_y) / h,
        )
    )
# Out:
# /content/drive/MyDrive/data/training_images/vid_4_1000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_10980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_11980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_12480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_13920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_14500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_15000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_15020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_15040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_16720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17600.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_17680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_18880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_1980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_19920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2100.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21600.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_21680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_22980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_23000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_23020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_24760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_2540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_26580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_28860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_30000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_30000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_29960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_30020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_30020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_30440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3120.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3140.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_3840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_4540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_4520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_4560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_600.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6160.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6180.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6360.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6380.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6400.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6480.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_6520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8600.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8680.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_8980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9000.jpg
# /content/drive/MyDrive/data/training_images/vid_4_900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9020.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9040.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9060.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9080.jpg
# /content/drive/MyDrive/data/training_images/vid_4_920.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9200.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9220.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9240.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9260.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9280.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9300.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9320.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9340.jpg
# /content/drive/MyDrive/data/training_images/vid_4_940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_940.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9420.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9460.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9440.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9500.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9520.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9540.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9560.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9580.jpg
# /content/drive/MyDrive/data/training_images/vid_4_960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9600.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9600.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9640.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9660.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9620.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9720.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9760.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9740.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9700.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9780.jpg
# /content/drive/MyDrive/data/training_images/vid_4_980.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9800.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9820.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9840.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9860.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9880.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9900.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9960.jpg
# /content/drive/MyDrive/data/training_images/vid_4_9980.jpg

# %%
print(len(images))
print(len(targets))
# Out:
# 559
# 559

# %%
(x_train), (y_train) = (
    np.asarray(images[: int(len(images) * 0.8)]),
    np.asarray(targets[: int(len(targets) * 0.8)]),
)
(x_test), (y_test) = (
    np.asarray(images[int(len(images) * 0.8) :]),
    np.asarray(targets[int(len(targets) * 0.8) :]),
)

# %%
print(len(x_train))
print(len(y_train))
# Out:
# 447
# 447

# %%
print(len(x_test))
print(len(y_test))
# Out:
# 112
# 112

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    #     Override function to avoid error while saving model
    def get_config(self):
        config = super().get_config().copy()
        config.update(
            {
                "input_shape": input_shape,
                "patch_size": patch_size,
                "num_patches": num_patches,
                "projection_dim": projection_dim,
                "num_heads": num_heads,
                "transformer_units": transformer_units,
                "transformer_layers": transformer_layers,
                "mlp_head_units": mlp_head_units,
            }
        )
        return config

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        # return patches
        return tf.reshape(patches, [batch_size, -1, patches.shape[-1]])

# %%
patch_size = 32  # Size of the patches to be extracted from the input images

plt.figure(figsize=(4, 4))
plt.imshow(x_train[0].astype("uint8"))
plt.axis("off")

patches = Patches(patch_size)(tf.convert_to_tensor([x_train[0]]))
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"{patches.shape[1]} patches per image \n{patches.shape[-1]} elements per patch")


n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 224 X 224
# Patch size: 32 X 32
# 49 patches per image
# 3072 elements per patch

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    # Override function to avoid error while saving model
    def get_config(self):
        config = super().get_config().copy()
        config.update(
            {
                "input_shape": input_shape,
                "patch_size": patch_size,
                "num_patches": num_patches,
                "projection_dim": projection_dim,
                "num_heads": num_heads,
                "transformer_units": transformer_units,
                "transformer_layers": transformer_layers,
                "mlp_head_units": mlp_head_units,
            }
        )
        return config

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
):
    inputs = layers.Input(shape=input_shape)
    # Create patches
    patches = Patches(patch_size)(inputs)
    # Encode patches
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.3)

    bounding_box = layers.Dense(4)(
        features
    )  # Final four neurons that output bounding box

    # return Keras model.
    return keras.Model(inputs=inputs, outputs=bounding_box)

# %%
def run_experiment(model, learning_rate, weight_decay, batch_size, num_epochs):

    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    # Compile model.
    model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError())

    checkpoint_filepath = "logs/"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[
            checkpoint_callback,
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=10),
        ],
    )

    return history


input_shape = (image_size, image_size, 3)  # input image shape
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 100
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
# Size of the transformer layers
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [2048, 1024, 512, 64, 32]  # Size of the dense layers


history = []
num_patches = (image_size // patch_size) ** 2

vit_object_detector = create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
)

# Train model
history = run_experiment(
    vit_object_detector, learning_rate, weight_decay, batch_size, num_epochs
)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 16s 147ms/step - loss: 0.8857 - val_loss: 0.3342
# Epoch 2/100
# 13/13 [==============================] - 1s 72ms/step - loss: 0.4211 - val_loss: 0.2991
# Epoch 3/100
# 13/13 [==============================] - 1s 89ms/step - loss: 0.3192 - val_loss: 0.2770
# Epoch 4/100
# 13/13 [==============================] - 1s 95ms/step - loss: 0.2690 - val_loss: 0.2542
# Epoch 5/100
# 13/13 [==============================] - 1s 97ms/step - loss: 0.2436 - val_loss: 0.2322
# Epoch 6/100
# 13/13 [==============================] - 2s 150ms/step - loss: 0.2183 - val_loss: 0.2115
# Epoch 7/100
# 13/13 [==============================] - 4s 293ms/step - loss: 0.2062 - val_loss: 0.1921
# Epoch 8/100
# 13/13 [==============================] - 1s 73ms/step - loss: 0.1801 - val_loss: 0.1742
# Epoch 9/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.1631 - val_loss: 0.1573
# Epoch 10/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.1470 - val_loss: 0.1418
# Epoch 11/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.1376 - val_loss: 0.1273
# Epoch 12/100
# 13/13 [==============================] - 1s 76ms/step - loss: 0.1473 - val_loss: 0.1141
# Epoch 13/100
# 13/13 [==============================] - 1s 74ms/step - loss: 0.1145 - val_loss: 0.1025
# Epoch 14/100
# 13/13 [==============================] - 3s 271ms/step - loss: 0.0965 - val_loss: 0.0923
# Epoch 15/100
# 13/13 [==============================] - 1s 94ms/step - loss: 0.0876 - val_loss: 0.0830
# Epoch 16/100
# 13/13 [==============================] - 1s 101ms/step - loss: 0.0780 - val_loss: 0.0751
# Epoch 17/100
# 13/13 [==============================] - 2s 189ms/step - loss: 0.0825 - val_loss: 0.0689
# Epoch 18/100
# 13/13 [==============================] - 1s 74ms/step - loss: 0.0720 - val_loss: 0.0640
# Epoch 19/100
# 13/13 [==============================] - 1s 72ms/step - loss: 0.0647 - val_loss: 0.0600
# Epoch 20/100
# 13/13 [==============================] - 3s 272ms/step - loss: 0.0596 - val_loss: 0.0571
# Epoch 21/100
# 13/13 [==============================] - 1s 78ms/step - loss: 0.0558 - val_loss: 0.0550
# Epoch 22/100
# 13/13 [==============================] - 1s 77ms/step - loss: 0.0561 - val_loss: 0.0535
# Epoch 23/100
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0559 - val_loss: 0.0524
# Epoch 24/100
# 13/13 [==============================] - 1s 95ms/step - loss: 0.0547 - val_loss: 0.0517
# Epoch 25/100
# 13/13 [==============================] - 1s 95ms/step - loss: 0.0540 - val_loss: 0.0513
# Epoch 26/100
# 13/13 [==============================] - 1s 94ms/step - loss: 0.0532 - val_loss: 0.0510
# Epoch 27/100
# 13/13 [==============================] - 3s 251ms/step - loss: 0.0532 - val_loss: 0.0508
# Epoch 28/100
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0525 - val_loss: 0.0508
# Epoch 29/100
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0519 - val_loss: 0.0507
# Epoch 30/100
# 13/13 [==============================] - 3s 241ms/step - loss: 0.0525 - val_loss: 0.0506
# Epoch 31/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0524 - val_loss: 0.0506
# Epoch 32/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0529 - val_loss: 0.0506
# Epoch 33/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0530 - val_loss: 0.0506
# Epoch 34/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0528 - val_loss: 0.0506
# Epoch 35/100
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0523 - val_loss: 0.0506
# Epoch 36/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0520 - val_loss: 0.0505
# Epoch 37/100
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0524 - val_loss: 0.0504
# Epoch 38/100
# 13/13 [==============================] - 1s 102ms/step - loss: 0.0520 - val_loss: 0.0504
# Epoch 39/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0514 - val_loss: 0.0505
# Epoch 40/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0515 - val_loss: 0.0505
# Epoch 41/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0535 - val_loss: 0.0505
# Epoch 42/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0519 - val_loss: 0.0505
# Epoch 43/100
# 13/13 [==============================] - 1s 98ms/step - loss: 0.0511 - val_loss: 0.0504
# Epoch 44/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0519 - val_loss: 0.0504
# Epoch 45/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0535 - val_loss: 0.0505
# Epoch 46/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0519 - val_loss: 0.0505
# Epoch 47/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0513 - val_loss: 0.0505
# Epoch 48/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0522 - val_loss: 0.0505
# Epoch 49/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0518 - val_loss: 0.0504
# Epoch 50/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0512 - val_loss: 0.0504
# Epoch 51/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0520 - val_loss: 0.0503
# Epoch 52/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0535 - val_loss: 0.0504
# Epoch 53/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0526 - val_loss: 0.0505
# Epoch 54/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0521 - val_loss: 0.0504
# Epoch 55/100
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0522 - val_loss: 0.0505
# Epoch 56/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0520 - val_loss: 0.0504
# Epoch 57/100
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0519 - val_loss: 0.0505
# Epoch 58/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0520 - val_loss: 0.0505
# Epoch 59/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0516 - val_loss: 0.0504
# Epoch 60/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0520 - val_loss: 0.0505
# Epoch 61/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0524 - val_loss: 0.0505

# %%
import matplotlib.patches as patches

# Saves the model in current path
vit_object_detector.save("vit_object_detector.h5", save_format="h5")

# To calculate IoU (intersection over union, given two bounding boxes)
def bounding_box_intersection_over_union(box_predicted, box_truth):
    # get (x, y) coordinates of intersection of bounding boxes
    top_x_intersect = max(box_predicted[0], box_truth[0])
    top_y_intersect = max(box_predicted[1], box_truth[1])
    bottom_x_intersect = min(box_predicted[2], box_truth[2])
    bottom_y_intersect = min(box_predicted[3], box_truth[3])

    # calculate area of the intersection bb (bounding box)
    intersection_area = max(0, bottom_x_intersect - top_x_intersect + 1) * max(
        0, bottom_y_intersect - top_y_intersect + 1
    )

    # calculate area of the prediction bb and ground-truth bb
    box_predicted_area = (box_predicted[2] - box_predicted[0] + 1) * (
        box_predicted[3] - box_predicted[1] + 1
    )
    box_truth_area = (box_truth[2] - box_truth[0] + 1) * (
        box_truth[3] - box_truth[1] + 1
    )

    # calculate intersection over union by taking intersection
    # area and dividing it by the sum of predicted bb and ground truth
    # bb areas subtracted by  the interesection area

    # return ioU
    return intersection_area / float(
        box_predicted_area + box_truth_area - intersection_area
    )


i, mean_iou = 0, 0

# Compare results for 10 images in the test set
for input_image in x_test[10:]:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 15))
    im = input_image

    # Display the image
    ax1.imshow(im.astype("uint8"))
    ax2.imshow(im.astype("uint8"))

    input_image = cv2.resize(
        input_image, (image_size, image_size), interpolation=cv2.INTER_AREA
    )
    input_image = np.expand_dims(input_image, axis=0)
    preds = vit_object_detector.predict(input_image)[0]

    (h, w) = (im).shape[0:2]

    top_left_x, top_left_y = int(preds[0] * w), int(preds[1] * h)

    bottom_right_x, bottom_right_y = int(preds[2] * w), int(preds[3] * h)

    box_predicted = [top_left_x, top_left_y, bottom_right_x, bottom_right_y]
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax1.add_patch(rect)
    ax1.set_xlabel(
        "Predicted: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
    )

    top_left_x, top_left_y = int(y_test[i][0] * w), int(y_test[i][1] * h)

    bottom_right_x, bottom_right_y = int(y_test[i][2] * w), int(y_test[i][3] * h)

    box_truth = top_left_x, top_left_y, bottom_right_x, bottom_right_y

    mean_iou += bounding_box_intersection_over_union(box_predicted, box_truth)
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax2.add_patch(rect)
    ax2.set_xlabel(
        "Target: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
        + "\n"
        + "IoU"
        + str(bounding_box_intersection_over_union(box_predicted, box_truth))
    )
    i = i + 1

print("mean_iou: " + str(mean_iou / len(x_test[:10])))
plt.show()

# %% [markdown]
# ##Cell outputs were cleared for decreasing size

# %%
test_image_path="/content/drive/MyDrive/data/testing_images"
test_image_paths = [
    f for f in os.listdir(test_image_path) if os.path.isfile(os.path.join(test_image_path, f))
]
test_images=[]
for i in range(len(test_image_path)):
  timage = keras.utils.load_img(path_images + image_paths[i],)
  test_images.append(keras.utils.img_to_array(timage))
test_images=np.asarray(test_images)

for input_image in test_images:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 15))
    im = input_image

    # Display the image
    ax1.imshow(im.astype("uint8"))
    ax2.imshow(im.astype("uint8"))
    input_image = cv2.resize(
        input_image, (image_size, image_size), interpolation=cv2.INTER_AREA
    )
    input_image = np.expand_dims(input_image, axis=0)
    preds = vit_object_detector.predict(input_image)[0]

    (h, w) = (im).shape[0:2]

    top_left_x, top_left_y = int(preds[0] * w), int(preds[1] * h)

    bottom_right_x, bottom_right_y = int(preds[2] * w), int(preds[3] * h)

    box_predicted = [top_left_x, top_left_y, bottom_right_x, bottom_right_y]
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax1.add_patch(rect)
    ax1.set_xlabel(
        "Predicted: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
    )

# %% [markdown]
# ##Cell outputs were cleared for decreasing size
